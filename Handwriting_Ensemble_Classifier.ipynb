# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshsaxena24/Deep-Learning-UEC642--Project/blob/main/Handwriting_Ensemble_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

print("TensorFlow version:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test  = x_test.astype("float32") / 255.0
x_train = x_train[..., tf.newaxis]
x_test  = x_test[..., tf.newaxis]

num_classes = 10
y_train_oh = tf.keras.utils.to_categorical(y_train, num_classes=num_classes)
y_test_oh  = tf.keras.utils.to_categorical(y_test, num_classes=num_classes)

from tensorflow.keras.layers import SeparableConv2D

def build_separable_cnn(input_shape=(28, 28, 1), num_classes=10):
    model = models.Sequential([
        SeparableConv2D(32, (3, 3), padding="same", activation="relu",
                        input_shape=input_shape),
        SeparableConv2D(32, (3, 3), activation="relu"),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        SeparableConv2D(64, (3, 3), padding="same", activation="relu"),
        SeparableConv2D(64, (3, 3), activation="relu"),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        layers.Flatten(),
        layers.Dense(128, activation="relu"),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax")
    ])
    return model

model = build_separable_cnn()
model.summary()

loss_fn = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss=loss_fn,
    metrics=["accuracy"]
)


models_list = []
num_models = 3

for i in range(num_models):
    print(f"\nTraining model {i+1}/{num_models}")
    m = build_separable_cnn()
    m.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
        loss=loss_fn,
        metrics=["accuracy"]
    )
    m.fit(
        x_train, y_train_oh,
        batch_size=128,
        epochs=20,
        validation_split=0.1,
        callbacks=[early_stop, reduce_lr],
        verbose=2
    )
    models_list.append(m)

import numpy as np

probs = [m.predict(x_test, verbose=0) for m in models_list]
probs_mean = np.mean(probs, axis=0)
y_pred = np.argmax(probs_mean, axis=1)
ensemble_acc = np.mean(y_pred == y_test)

print(f"Single best model acc ≈ {max(m.evaluate(x_test, y_test_oh, verbose=0)[1] for m in models_list):.4f}")
print(f"Ensemble accuracy: {ensemble_acc:.4f}")

early_stop = EarlyStopping(
    monitor="val_accuracy",
    patience=3,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=2,
    min_lr=1e-5
)

history = model.fit(
    x_train, y_train_oh,
    batch_size=128,
    epochs=25,
    validation_split=0.1,
    callbacks=[early_stop, reduce_lr],
    verbose=2
)

test_loss, test_acc = model.evaluate(x_test, y_test_oh, verbose=0)
print(f"Test accuracy with separable conv + label smoothing: {test_acc:.4f}")
# Out:
# TensorFlow version: 2.19.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ separable_conv2d_4              │ (None, 28, 28, 32)     │            73 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_5              │ (None, 26, 26, 32)     │         1,344 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_6              │ (None, 13, 13, 64)     │         2,400 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_7              │ (None, 11, 11, 64)     │         4,736 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 214,771 (838.95 KB)
#  Trainable params: 214,771 (838.95 KB)
#  Non-trainable params: 0 (0.00 B)
# Training model 1/3
# Epoch 1/20
# 422/422 - 15s - 36ms/step - accuracy: 0.8026 - loss: 1.0518 - val_accuracy: 0.9697 - val_loss: 0.6356 - learning_rate: 1.0000e-03
# Epoch 2/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9529 - loss: 0.7191 - val_accuracy: 0.9817 - val_loss: 0.5930 - learning_rate: 1.0000e-03
# Epoch 3/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9664 - loss: 0.6804 - val_accuracy: 0.9863 - val_loss: 0.5747 - learning_rate: 1.0000e-03
# Epoch 4/20
# 422/422 - 3s - 7ms/step - accuracy: 0.9713 - loss: 0.6611 - val_accuracy: 0.9885 - val_loss: 0.5657 - learning_rate: 1.0000e-03
# Epoch 5/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9761 - loss: 0.6460 - val_accuracy: 0.9892 - val_loss: 0.5592 - learning_rate: 1.0000e-03
# Epoch 6/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9784 - loss: 0.6368 - val_accuracy: 0.9898 - val_loss: 0.5531 - learning_rate: 1.0000e-03
# Epoch 7/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9799 - loss: 0.6301 - val_accuracy: 0.9905 - val_loss: 0.5535 - learning_rate: 1.0000e-03
# Epoch 8/20
# 422/422 - 3s - 7ms/step - accuracy: 0.9823 - loss: 0.6242 - val_accuracy: 0.9913 - val_loss: 0.5477 - learning_rate: 1.0000e-03
# Epoch 9/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9836 - loss: 0.6192 - val_accuracy: 0.9907 - val_loss: 0.5492 - learning_rate: 1.0000e-03
# Epoch 10/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9844 - loss: 0.6154 - val_accuracy: 0.9913 - val_loss: 0.5453 - learning_rate: 1.0000e-03
# Epoch 11/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9847 - loss: 0.6115 - val_accuracy: 0.9923 - val_loss: 0.5518 - learning_rate: 1.0000e-03
# Epoch 12/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9861 - loss: 0.6078 - val_accuracy: 0.9923 - val_loss: 0.5450 - learning_rate: 1.0000e-03
# Epoch 13/20
# 422/422 - 3s - 7ms/step - accuracy: 0.9860 - loss: 0.6063 - val_accuracy: 0.9925 - val_loss: 0.5398 - learning_rate: 1.0000e-03
# Epoch 14/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9868 - loss: 0.6039 - val_accuracy: 0.9927 - val_loss: 0.5405 - learning_rate: 1.0000e-03
# Epoch 15/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9877 - loss: 0.6013 - val_accuracy: 0.9933 - val_loss: 0.5412 - learning_rate: 1.0000e-03
# Epoch 16/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9884 - loss: 0.5970 - val_accuracy: 0.9935 - val_loss: 0.5378 - learning_rate: 5.0000e-04
# Epoch 17/20
# 422/422 - 3s - 7ms/step - accuracy: 0.9894 - loss: 0.5940 - val_accuracy: 0.9918 - val_loss: 0.5385 - learning_rate: 5.0000e-04
# Epoch 18/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9888 - loss: 0.5944 - val_accuracy: 0.9937 - val_loss: 0.5378 - learning_rate: 5.0000e-04
# Epoch 19/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9901 - loss: 0.5919 - val_accuracy: 0.9935 - val_loss: 0.5361 - learning_rate: 2.5000e-04
# Epoch 20/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9901 - loss: 0.5913 - val_accuracy: 0.9933 - val_loss: 0.5342 - learning_rate: 2.5000e-04
#
# Training model 2/3
# Epoch 1/20
# 422/422 - 16s - 37ms/step - accuracy: 0.7578 - loss: 1.1407 - val_accuracy: 0.9627 - val_loss: 0.6551 - learning_rate: 1.0000e-03
# Epoch 2/20
# 422/422 - 3s - 7ms/step - accuracy: 0.9384 - loss: 0.7631 - val_accuracy: 0.9775 - val_loss: 0.6097 - learning_rate: 1.0000e-03
# Epoch 3/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9558 - loss: 0.7130 - val_accuracy: 0.9823 - val_loss: 0.5927 - learning_rate: 1.0000e-03
# Epoch 4/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9654 - loss: 0.6867 - val_accuracy: 0.9852 - val_loss: 0.5739 - learning_rate: 1.0000e-03
# Epoch 5/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9692 - loss: 0.6716 - val_accuracy: 0.9882 - val_loss: 0.5681 - learning_rate: 1.0000e-03
# Epoch 6/20
# 422/422 - 3s - 7ms/step - accuracy: 0.9738 - loss: 0.6589 - val_accuracy: 0.9875 - val_loss: 0.5664 - learning_rate: 1.0000e-03
# Epoch 7/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9767 - loss: 0.6489 - val_accuracy: 0.9912 - val_loss: 0.5572 - learning_rate: 1.0000e-03
# Epoch 8/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9797 - loss: 0.6391 - val_accuracy: 0.9910 - val_loss: 0.5532 - learning_rate: 1.0000e-03
# Epoch 9/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9808 - loss: 0.6339 - val_accuracy: 0.9907 - val_loss: 0.5520 - learning_rate: 1.0000e-03
# Epoch 10/20
# 422/422 - 3s - 7ms/step - accuracy: 0.9823 - loss: 0.6277 - val_accuracy: 0.9920 - val_loss: 0.5557 - learning_rate: 1.0000e-03
# Epoch 11/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9840 - loss: 0.6230 - val_accuracy: 0.9927 - val_loss: 0.5430 - learning_rate: 1.0000e-03
# Epoch 12/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9842 - loss: 0.6195 - val_accuracy: 0.9920 - val_loss: 0.5433 - learning_rate: 1.0000e-03
# Epoch 13/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9852 - loss: 0.6172 - val_accuracy: 0.9932 - val_loss: 0.5547 - learning_rate: 1.0000e-03
# Epoch 14/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9867 - loss: 0.6100 - val_accuracy: 0.9927 - val_loss: 0.5427 - learning_rate: 5.0000e-04
# Epoch 15/20
# 422/422 - 3s - 7ms/step - accuracy: 0.9873 - loss: 0.6085 - val_accuracy: 0.9930 - val_loss: 0.5427 - learning_rate: 5.0000e-04
# Epoch 16/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9875 - loss: 0.6071 - val_accuracy: 0.9925 - val_loss: 0.5422 - learning_rate: 5.0000e-04
#
# Training model 3/3
# Epoch 1/20
# 422/422 - 15s - 35ms/step - accuracy: 0.7765 - loss: 1.1014 - val_accuracy: 0.9700 - val_loss: 0.6365 - learning_rate: 1.0000e-03
# Epoch 2/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9493 - loss: 0.7354 - val_accuracy: 0.9810 - val_loss: 0.5928 - learning_rate: 1.0000e-03
# Epoch 3/20
# 422/422 - 3s - 7ms/step - accuracy: 0.9642 - loss: 0.6868 - val_accuracy: 0.9845 - val_loss: 0.5808 - learning_rate: 1.0000e-03
# Epoch 4/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9718 - loss: 0.6621 - val_accuracy: 0.9867 - val_loss: 0.5786 - learning_rate: 1.0000e-03
# Epoch 5/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9755 - loss: 0.6492 - val_accuracy: 0.9872 - val_loss: 0.5576 - learning_rate: 1.0000e-03
# Epoch 6/20
# 422/422 - 5s - 13ms/step - accuracy: 0.9778 - loss: 0.6401 - val_accuracy: 0.9885 - val_loss: 0.5561 - learning_rate: 1.0000e-03
# Epoch 7/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9803 - loss: 0.6333 - val_accuracy: 0.9888 - val_loss: 0.5569 - learning_rate: 1.0000e-03
# Epoch 8/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9815 - loss: 0.6272 - val_accuracy: 0.9907 - val_loss: 0.5479 - learning_rate: 1.0000e-03
# Epoch 9/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9828 - loss: 0.6234 - val_accuracy: 0.9905 - val_loss: 0.5500 - learning_rate: 1.0000e-03
# Epoch 10/20
# 422/422 - 3s - 6ms/step - accuracy: 0.9839 - loss: 0.6199 - val_accuracy: 0.9907 - val_loss: 0.5455 - learning_rate: 1.0000e-03
# Epoch 11/20
# 422/422 - 3s - 7ms/step - accuracy: 0.9850 - loss: 0.6162 - val_accuracy: 0.9907 - val_loss: 0.5479 - learning_rate: 1.0000e-03
# Single best model acc ≈ 0.9936
# Ensemble accuracy: 0.9928
# Epoch 1/25
# 422/422 - 14s - 34ms/step - accuracy: 0.7901 - loss: 1.0773 - val_accuracy: 0.9663 - val_loss: 0.6416 - learning_rate: 1.0000e-03
# Epoch 2/25
# 422/422 - 3s - 6ms/step - accuracy: 0.9480 - loss: 0.7331 - val_accuracy: 0.9813 - val_loss: 0.5937 - learning_rate: 1.0000e-03
# Epoch 3/25
# 422/422 - 3s - 7ms/step - accuracy: 0.9626 - loss: 0.6914 - val_accuracy: 0.9858 - val_loss: 0.5809 - learning_rate: 1.0000e-03
# Epoch 4/25
# 422/422 - 3s - 6ms/step - accuracy: 0.9699 - loss: 0.6692 - val_accuracy: 0.9875 - val_loss: 0.5677 - learning_rate: 1.0000e-03
# Epoch 5/25
# 422/422 - 5s - 12ms/step - accuracy: 0.9739 - loss: 0.6533 - val_accuracy: 0.9895 - val_loss: 0.5630 - learning_rate: 1.0000e-03
# Epoch 6/25
# 422/422 - 3s - 6ms/step - accuracy: 0.9771 - loss: 0.6420 - val_accuracy: 0.9900 - val_loss: 0.5562 - learning_rate: 1.0000e-03
# Epoch 7/25
# 422/422 - 3s - 7ms/step - accuracy: 0.9791 - loss: 0.6357 - val_accuracy: 0.9915 - val_loss: 0.5516 - learning_rate: 1.0000e-03
# Epoch 8/25
# 422/422 - 3s - 6ms/step - accuracy: 0.9808 - loss: 0.6282 - val_accuracy: 0.9915 - val_loss: 0.5578 - learning_rate: 1.0000e-03
# Epoch 9/25
# 422/422 - 3s - 6ms/step - accuracy: 0.9826 - loss: 0.6230 - val_accuracy: 0.9922 - val_loss: 0.5490 - learning_rate: 1.0000e-03
# Epoch 10/25
# 422/422 - 3s - 6ms/step - accuracy: 0.9835 - loss: 0.6198 - val_accuracy: 0.9927 - val_loss: 0.5487 - learning_rate: 1.0000e-03
# Epoch 11/25
# 422/422 - 3s - 7ms/step - accuracy: 0.9850 - loss: 0.6158 - val_accuracy: 0.9935 - val_loss: 0.5468 - learning_rate: 1.0000e-03
# Epoch 12/25
# 422/422 - 5s - 12ms/step - accuracy: 0.9851 - loss: 0.6130 - val_accuracy: 0.9928 - val_loss: 0.5454 - learning_rate: 1.0000e-03
# Epoch 13/25
# 422/422 - 3s - 6ms/step - accuracy: 0.9874 - loss: 0.6083 - val_accuracy: 0.9928 - val_loss: 0.5442 - learning_rate: 1.0000e-03
# Epoch 14/25
# 422/422 - 3s - 6ms/step - accuracy: 0.9864 - loss: 0.6076 - val_accuracy: 0.9933 - val_loss: 0.5406 - learning_rate: 1.0000e-03
# Test accuracy with separable conv + label smoothing: 0.9918
